# %% [markdown]
# <a href="https://colab.research.google.com/github/alga2002/alga2002/blob/main/World_Cup_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Scope:*
#
# The goal of this analysis is to help me learn more about analytics, machine learning, and mathematical logic. I will be creating a collection of predictions here that will serve to guide my expectations in the world cup.
# It will follow 3 distinct logics:
#
# 1. Team Stats
# * The first analysis will only take under consideration data from previous World Cups on a team basis. It won't include the data from this world cup, since it is meant for predictions
#
# 2. Player Stats
# * The second analysis will utilize the data from each individual player. The analysis will be used to determine the results for the elimination rounds in this World Cup.
#
# 3. Combo
# * The Third interation will use a mix of both datasets and generate a weight criteria to determine which factor should impact the results more.
#
# 4. Real time analysis of movement
#
# * I want to create a model that interacts with the screen to check in real time the stats for each team. I am talking about ball posession, control, number of attacks, number of successful defenses, and tiredness.
#
# * The goal is to have the model screening my TV in real time to check for the player movement, identyfying colors to distinguish teams and movement to distinguishi otehr patterns as well as defensive mistakes and great attack patterns.
#
# * With this I hope to understand soccer at a deeper level, and find new patterns I didn't know before for professional games, as well as determining what factors influence the teams performance more.

# %%
#Imports

# %%
#Datasets
